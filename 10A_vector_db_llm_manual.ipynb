# %%
# 📦 Install packages
# %pip install openai chromadb python-dotenv
# Out:
# Requirement already satisfied: openai in ./venv/lib/python3.12/site-packages (1.82.0)
# Requirement already satisfied: chromadb in ./venv/lib/python3.12/site-packages (1.0.10)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.12/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.12/site-packages (from openai) (2.11.5)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./venv/lib/python3.12/site-packages (from openai) (4.13.2)
# Requirement already satisfied: build>=1.0.3 in ./venv/lib/python3.12/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in ./venv/lib/python3.12/site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in ./venv/lib/python3.12/site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog>=2.4.0 in ./venv/lib/python3.12/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./venv/lib/python3.12/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./venv/lib/python3.12/site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./venv/lib/python3.12/site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./venv/lib/python3.12/site-packages (from chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./venv/lib/python3.12/site-packages (from chromadb) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in ./venv/lib/python3.12/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in ./venv/lib/python3.12/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in ./venv/lib/python3.12/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./venv/lib/python3.12/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./venv/lib/python3.12/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in ./venv/lib/python3.12/site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./venv/lib/python3.12/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in ./venv/lib/python3.12/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in ./venv/lib/python3.12/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in ./venv/lib/python3.12/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in ./venv/lib/python3.12/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.12/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in ./venv/lib/python3.12/site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./venv/lib/python3.12/site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: packaging>=19.1 in ./venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in ./venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in ./venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in ./venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in ./venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in ./venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.32.2)
# Requirement already satisfied: click>=8.0.0 in ./venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.2)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.22.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.2)
# Requirement already satisfied: humanfriendly>=9.1 in ./venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 🔍 RAG using ChromaDB + OpenAI (Manual Version)
# This notebook loads documents, creates embeddings manually, and retrieves chunks from ChromaDB.

# %%
import os
from dotenv import load_dotenv
import chromadb
from openai import OpenAI
from chromadb.utils import embedding_functions

# Load environment variables from .env file
load_dotenv()
openai_key = os.getenv("OPENAI_API_KEY")

openai_ef = embedding_functions.OpenAIEmbeddingFunction(
    api_key=openai_key, model_name="text-embedding-3-small"
)

# Initialize the Chroma client with persistence
chroma_client = chromadb.PersistentClient(path="./db/chroma_persistent_storage")
collection_name = "document_qa_collection"
collection = chroma_client.get_or_create_collection(
    name=collection_name, embedding_function=openai_ef
)

client = OpenAI(api_key=openai_key)

# %%
# Load documents
def load_documents_from_directory(directory_path):
    print("==== Loading documents from directory ====")
    documents = []
    for filename in os.listdir(directory_path):
        if filename.endswith(".txt"):
            with open(os.path.join(directory_path, filename), "r", encoding="utf-8") as file:
                documents.append({"id": filename, "text": file.read()})
    return documents

# Split documents
def split_text(text, chunk_size=1000, chunk_overlap=20):
    chunks = []
    start = 0
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start = end - chunk_overlap
    return chunks

directory_path = "./data/new_articles"
documents = load_documents_from_directory(directory_path)

chunked_documents = []
for doc in documents:
    chunks = split_text(doc["text"])
    for i, chunk in enumerate(chunks):
        chunked_documents.append({"id": f"{doc['id']}_chunk{i+1}", "text": chunk})
# Out:
# ==== Loading documents from directory ====

# %%
# Generate embeddings, this can take 1 min+
def get_openai_embedding(text):
    response = client.embeddings.create(input=text, model="text-embedding-3-small")
    return response.data[0].embedding

for doc in chunked_documents:
    doc["embedding"] = get_openai_embedding(doc["text"])
    collection.upsert(ids=[doc["id"]], documents=[doc["text"]], embeddings=[doc["embedding"]])

# comment above, and execute below to see how it processing
#for idx, doc in enumerate(chunked_documents):
#    print(f"Embedding chunk {idx+1}/{len(chunked_documents)}: {doc['id']}")
#    doc["embedding"] = get_openai_embedding(doc["text"])
#    collection.upsert(ids=[doc["id"]], documents=[doc["text"]], embeddings=[doc["embedding"]])
# Out:
# Embedding chunk 1/184: 05-03-ai-powered-supply-chain-startup-pando-lands-30m-investment.txt_chunk1
# Embedding chunk 2/184: 05-03-ai-powered-supply-chain-startup-pando-lands-30m-investment.txt_chunk2
# Embedding chunk 3/184: 05-03-ai-powered-supply-chain-startup-pando-lands-30m-investment.txt_chunk3
# Embedding chunk 4/184: 05-03-ai-powered-supply-chain-startup-pando-lands-30m-investment.txt_chunk4
# Embedding chunk 5/184: 05-03-ai-powered-supply-chain-startup-pando-lands-30m-investment.txt_chunk5
# Embedding chunk 6/184: 05-03-ai-powered-supply-chain-startup-pando-lands-30m-investment.txt_chunk6
# Embedding chunk 7/184: 05-03-ai-replace-tv-writers-strike.txt_chunk1
# Embedding chunk 8/184: 05-03-ai-replace-tv-writers-strike.txt_chunk2
# Embedding chunk 9/184: 05-03-ai-replace-tv-writers-strike.txt_chunk3
# Embedding chunk 10/184: 05-03-ai-replace-tv-writers-strike.txt_chunk4
# Embedding chunk 11/184: 05-03-ai-replace-tv-writers-strike.txt_chunk5
# Embedding chunk 12/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk1
# Embedding chunk 13/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk2
# Embedding chunk 14/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk3
# Embedding chunk 15/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk4
# Embedding chunk 16/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk5
# Embedding chunk 17/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk6
# Embedding chunk 18/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk7
# Embedding chunk 19/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk8
# Embedding chunk 20/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk9
# Embedding chunk 21/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk10
# Embedding chunk 22/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk11
# Embedding chunk 23/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk12
# Embedding chunk 24/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk13
# Embedding chunk 25/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk14
# Embedding chunk 26/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk15
# Embedding chunk 27/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk16
# Embedding chunk 28/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk17
# Embedding chunk 29/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk18
# Embedding chunk 30/184: 05-03-chatgpt-everything-you-need-to-know-about-the-ai-powered-chatbot.txt_chunk19
# Embedding chunk 31/184: 05-03-checks-the-ai-powered-data-protection-project-incubated-in-area-120-officially-exits-to-google.txt_chunk1
# Embedding chunk 32/184: 05-03-checks-the-ai-powered-data-protection-project-incubated-in-area-120-officially-exits-to-google.txt_chunk2
# Embedding chunk 33/184: 05-03-checks-the-ai-powered-data-protection-project-incubated-in-area-120-officially-exits-to-google.txt_chunk3
# Embedding chunk 34/184: 05-03-checks-the-ai-powered-data-protection-project-incubated-in-area-120-officially-exits-to-google.txt_chunk4
# Embedding chunk 35/184: 05-03-checks-the-ai-powered-data-protection-project-incubated-in-area-120-officially-exits-to-google.txt_chunk5
# Embedding chunk 36/184: 05-03-databricks-acquires-ai-centric-data-governance-platform-okera.txt_chunk1
# Embedding chunk 37/184: 05-03-databricks-acquires-ai-centric-data-governance-platform-okera.txt_chunk2
# Embedding chunk 38/184: 05-03-databricks-acquires-ai-centric-data-governance-platform-okera.txt_chunk3
# Embedding chunk 39/184: 05-03-databricks-acquires-ai-centric-data-governance-platform-okera.txt_chunk4
# Embedding chunk 40/184: 05-03-nova-is-building-guardrails-for-generative-ai-content-to-protect-brand-integrity.txt_chunk1
# Embedding chunk 41/184: 05-03-nova-is-building-guardrails-for-generative-ai-content-to-protect-brand-integrity.txt_chunk2
# Embedding chunk 42/184: 05-03-nova-is-building-guardrails-for-generative-ai-content-to-protect-brand-integrity.txt_chunk3
# Embedding chunk 43/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk1
# Embedding chunk 44/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk2
# Embedding chunk 45/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk3
# Embedding chunk 46/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk4
# Embedding chunk 47/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk5
# Embedding chunk 48/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk6
# Embedding chunk 49/184: 05-03-spawning-lays-out-its-plans-for-letting-creators-opt-out-of-generative-ai-training.txt_chunk7
# Embedding chunk 50/184: 05-04-cma-generative-ai-review.txt_chunk1
# Embedding chunk 51/184: 05-04-cma-generative-ai-review.txt_chunk2
# Embedding chunk 52/184: 05-04-cma-generative-ai-review.txt_chunk3
# Embedding chunk 53/184: 05-04-cma-generative-ai-review.txt_chunk4
# Embedding chunk 54/184: 05-04-cma-generative-ai-review.txt_chunk5
# Embedding chunk 55/184: 05-04-cma-generative-ai-review.txt_chunk6
# Embedding chunk 56/184: 05-04-cma-generative-ai-review.txt_chunk7
# Embedding chunk 57/184: 05-04-cma-generative-ai-review.txt_chunk8
# Embedding chunk 58/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk1
# Embedding chunk 59/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk2
# Embedding chunk 60/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk3
# Embedding chunk 61/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk4
# Embedding chunk 62/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk5
# Embedding chunk 63/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk6
# Embedding chunk 64/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk7
# Embedding chunk 65/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk8
# Embedding chunk 66/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk9
# Embedding chunk 67/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk10
# Embedding chunk 68/184: 05-04-hugging-face-and-servicenow-release-a-free-code-generating-model.txt_chunk11
# Embedding chunk 69/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk1
# Embedding chunk 70/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk2
# Embedding chunk 71/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk3
# Embedding chunk 72/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk4
# Embedding chunk 73/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk5
# Embedding chunk 74/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk6
# Embedding chunk 75/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk7
# Embedding chunk 76/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk8
# Embedding chunk 77/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk9
# Embedding chunk 78/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk10
# Embedding chunk 79/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk11
# Embedding chunk 80/184: 05-04-microsoft-doubles-down-on-ai-with-new-bing-features.txt_chunk12
# Embedding chunk 81/184: 05-04-slack-updates-aim-to-put-ai-at-the-center-of-the-user-experience.txt_chunk1
# Embedding chunk 82/184: 05-04-slack-updates-aim-to-put-ai-at-the-center-of-the-user-experience.txt_chunk2
# Embedding chunk 83/184: 05-04-slack-updates-aim-to-put-ai-at-the-center-of-the-user-experience.txt_chunk3
# Embedding chunk 84/184: 05-04-slack-updates-aim-to-put-ai-at-the-center-of-the-user-experience.txt_chunk4
# Embedding chunk 85/184: 05-04-slack-updates-aim-to-put-ai-at-the-center-of-the-user-experience.txt_chunk5
# Embedding chunk 86/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk1
# Embedding chunk 87/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk2
# Embedding chunk 88/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk3
# Embedding chunk 89/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk4
# Embedding chunk 90/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk5
# Embedding chunk 91/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk6
# Embedding chunk 92/184: 05-05-google-and-openai-are-walmarts-besieged-by-fruit-stands.txt_chunk7
# Embedding chunk 93/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk1
# Embedding chunk 94/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk2
# Embedding chunk 95/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk3
# Embedding chunk 96/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk4
# Embedding chunk 97/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk5
# Embedding chunk 98/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk6
# Embedding chunk 99/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk7
# Embedding chunk 100/184: 05-05-google-i-o-2023-is-next-week-heres-what-were-expecting.txt_chunk8
# Embedding chunk 101/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk1
# Embedding chunk 102/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk2
# Embedding chunk 103/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk3
# Embedding chunk 104/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk4
# Embedding chunk 105/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk5
# Embedding chunk 106/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk6
# Embedding chunk 107/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk7
# Embedding chunk 108/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk8
# Embedding chunk 109/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk9
# Embedding chunk 110/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk10
# Embedding chunk 111/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk11
# Embedding chunk 112/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk12
# Embedding chunk 113/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk13
# Embedding chunk 114/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk14
# Embedding chunk 115/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk15
# Embedding chunk 116/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk16
# Embedding chunk 117/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk17
# Embedding chunk 118/184: 05-05-vint-cerf-on-the-exhilarating-mix-of-thrill-and-hazard-at-the-frontiers-of-tech.txt_chunk18
# Embedding chunk 119/184: 05-05-with-deepfloyd-generative-ai-art-gets-a-text-upgrade.txt_chunk1
# Embedding chunk 120/184: 05-05-with-deepfloyd-generative-ai-art-gets-a-text-upgrade.txt_chunk2
# Embedding chunk 121/184: 05-05-with-deepfloyd-generative-ai-art-gets-a-text-upgrade.txt_chunk3
# Embedding chunk 122/184: 05-05-with-deepfloyd-generative-ai-art-gets-a-text-upgrade.txt_chunk4
# Embedding chunk 123/184: 05-05-with-deepfloyd-generative-ai-art-gets-a-text-upgrade.txt_chunk5
# Embedding chunk 124/184: 05-05-with-deepfloyd-generative-ai-art-gets-a-text-upgrade.txt_chunk6
# Embedding chunk 125/184: 05-06-ai-startups-q1-investments.txt_chunk1
# Embedding chunk 126/184: 05-06-ai-startups-q1-investments.txt_chunk2
# Embedding chunk 127/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk1
# Embedding chunk 128/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk2
# Embedding chunk 129/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk3
# Embedding chunk 130/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk4
# Embedding chunk 131/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk5
# Embedding chunk 132/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk6
# Embedding chunk 133/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk7
# Embedding chunk 134/184: 05-06-amazon-launches-free-channels-check-marks-come-to-gmail-and-openai-raises-more-moolah.txt_chunk8
# Embedding chunk 135/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk1
# Embedding chunk 136/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk2
# Embedding chunk 137/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk3
# Embedding chunk 138/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk4
# Embedding chunk 139/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk5
# Embedding chunk 140/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk6
# Embedding chunk 141/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk7
# Embedding chunk 142/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk8
# Embedding chunk 143/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk9
# Embedding chunk 144/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk10
# Embedding chunk 145/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk11
# Embedding chunk 146/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk12
# Embedding chunk 147/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk13
# Embedding chunk 148/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk14
# Embedding chunk 149/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk15
# Embedding chunk 150/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk16
# Embedding chunk 151/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk17
# Embedding chunk 152/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk18
# Embedding chunk 153/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk19
# Embedding chunk 154/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk20
# Embedding chunk 155/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk21
# Embedding chunk 156/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk22
# Embedding chunk 157/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk23
# Embedding chunk 158/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk24
# Embedding chunk 159/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk25
# Embedding chunk 160/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk26
# Embedding chunk 161/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk27
# Embedding chunk 162/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk28
# Embedding chunk 163/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk29
# Embedding chunk 164/184: 05-06-this-week-in-apps-apple-and-google-team-up-on-trackers-google-i-o-preview-apps-hit-newfronts.txt_chunk30
# Embedding chunk 165/184: 05-07-3one4-capital-driven-by-contrarian-bets-raises-200-million-new-fund.txt_chunk1
# Embedding chunk 166/184: 05-07-3one4-capital-driven-by-contrarian-bets-raises-200-million-new-fund.txt_chunk2
# Embedding chunk 167/184: 05-07-3one4-capital-driven-by-contrarian-bets-raises-200-million-new-fund.txt_chunk3
# Embedding chunk 168/184: 05-07-3one4-capital-driven-by-contrarian-bets-raises-200-million-new-fund.txt_chunk4
# Embedding chunk 169/184: 05-07-3one4-capital-driven-by-contrarian-bets-raises-200-million-new-fund.txt_chunk5
# Embedding chunk 170/184: 05-07-3one4-capital-driven-by-contrarian-bets-raises-200-million-new-fund.txt_chunk6
# Embedding chunk 171/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk1
# Embedding chunk 172/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk2
# Embedding chunk 173/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk3
# Embedding chunk 174/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk4
# Embedding chunk 175/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk5
# Embedding chunk 176/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk6
# Embedding chunk 177/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk7
# Embedding chunk 178/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk8
# Embedding chunk 179/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk9
# Embedding chunk 180/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk10
# Embedding chunk 181/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk11
# Embedding chunk 182/184: 05-07-fintech-space-continues-to-be-competitive-and-drama-filled.txt_chunk12
# Embedding chunk 183/184: 05-07-spacex-starship-startups-future.txt_chunk1
# Embedding chunk 184/184: 05-07-spacex-starship-startups-future.txt_chunk2

# %%
# RAG Logic
def query_documents(question, n_results=2):
    results = collection.query(query_texts=question, n_results=n_results)
    return [doc for sublist in results["documents"] for doc in sublist]

def generate_response(question, relevant_chunks):
    context = "\n\n".join(relevant_chunks)
    prompt = (
        "You are an assistant for question-answering tasks. Use the following pieces of "
        "retrieved context to answer the question. If you don't know the answer, say that you "
        "don't know. Use three sentences maximum and keep the answer concise."
        "\n\nContext:\n" + context + "\n\nQuestion:\n" + question
    )
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "system", "content": prompt}, {"role": "user", "content": question}],
    )
    return response.choices[0].message.content

question = "give me a brief overview of the articles. Be concise, please."
relevant_chunks = query_documents(question)
answer = generate_response(question, relevant_chunks)

print("==== Answer ====")
print(answer)
# Out:
# ==== Answer ====
# The articles in the TechCrunch newsletter cover topics such as Lyft's equity struggles and new strategic direction, as well as the impact of down rounds on late-stage companies in the current funding market. Additionally, there are mentions of upcoming events like TC City Spotlight: Atlanta, TechCrunch Live with Persona and Index Ventures, and the Disrupt conference in San Francisco. TechCrunch+ subscribers gain access to detailed commentary, analysis, and surveys.
